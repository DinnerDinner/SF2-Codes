# %% [markdown]
# # part 1

# %% [markdown]
# import all necessary libraries (i.e. pandas and matplotlib)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Read the provided file `titanic.csv` into a DataFrame

# %%
titanic_df = pd.read_csv('titanic.csv', delimiter=',')

# %% [markdown]
# print the following
# - entries from the data frame
# - descriptive statistics, what is the average age, the maximum number of siblings and children?
# - general information
# - first 5 entries
# - first 15 entries
# - last 5 entries
# - last 15 entries
# - sample of random 10 entries

# %%
titanic_df
titanic_df.describe()
# titanic_df.info()
titanic_df.head()
titanic_df.head(15)
titanic_df.tail()
titanic_df.tail(15)
titanic_df.sample(10)
# Out:
#      survived  pclass     sex   age  sibsp      fare  class    who  \
# 515         0       1    male  47.0      0   34.0208  First    man
# 32          1       3  female   NaN      0    7.7500  Third  woman
# 819         0       3    male  10.0      3   27.9000  Third  child
# 258         1       1  female  35.0      0  512.3292  First  woman
# 12          0       3    male  20.0      0    8.0500  Third    man
# 826         0       3    male   NaN      0   56.4958  Third    man
# 514         0       3    male  24.0      0    7.4958  Third    man
# 363         0       3    male  35.0      0    7.0500  Third    man
# 828         1       3    male   NaN      0    7.7500  Third    man
# 374         0       3  female   3.0      3   21.0750  Third  child
#
#      adult_male deck  embark_town alive  alone
# 515        True    D  Southampton    no   True
# 32        False  NaN   Queenstown   yes   True
# 819       False  NaN  Southampton    no  False
# 258       False  NaN    Cherbourg   yes   True
# 12         True  NaN  Southampton    no   True
# 826        True  NaN  Southampton    no   True
# 514        True  NaN  Southampton    no   True
# 363        True  NaN  Southampton    no   True
# 828        True  NaN   Queenstown   yes   True
# 374       False  NaN  Southampton    no  False

# %% [markdown]
# draw a histogram for age distribution using `matplotlib`

# %%
plt.hist(titanic_df['age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# - Create a new DataFrame with only entries where age > 30.
# - Give number of such entires
# - show only the women entries, how many  are there over the age of 30
# - the men entries, how many men are there over the age of 30
# - plot the new histogram for all ages >30, how does this histogram differ from the one you plotted above?

# %%
age_30 = titanic_df['age']>30
titanic_df[age_30]
# Out:
#      survived  pclass     sex   age  sibsp     fare  class    who  adult_male  \
# 1           1       1  female  38.0      1  71.2833  First  woman       False
# 3           1       1  female  35.0      1  53.1000  First  woman       False
# 4           0       3    male  35.0      0   8.0500  Third    man        True
# 6           0       1    male  54.0      0  51.8625  First    man        True
# 11          1       1  female  58.0      0  26.5500  First  woman       False
# ..        ...     ...     ...   ...    ...      ...    ...    ...         ...
# 873         0       3    male  47.0      0   9.0000  Third    man        True
# 879         1       1  female  56.0      0  83.1583  First  woman       False
# 881         0       3    male  33.0      0   7.8958  Third    man        True
# 885         0       3  female  39.0      0  29.1250  Third  woman       False
# 890         0       3    male  32.0      0   7.7500  Third    man        True
#
#     deck  embark_town alive  alone
# 1      C    Cherbourg   yes  False
# 3      C  Southampton   yes  False
# 4    NaN  Southampton    no   True
# 6      E  Southampton    no   True
# 11     C  Southampton   yes   True
# ..   ...          ...   ...    ...
# 873  NaN  Southampton    no   True
# 879    C    Cherbourg   yes  False
# 881  NaN  Southampton    no   True
# 885  NaN   Queenstown    no  False
# 890  NaN   Queenstown    no   True
#
# [305 rows x 13 columns]

# %% [markdown]
# Use `pandas` to plot the pie chart of all classes on board the titanic.

# %%
# your code here

# %% [markdown]
# use `pandas` to plot the bar chart of all towns that people embarked from.

# %%
# your code here

# %% [markdown]
# # part 2

# %% [markdown]
# Create a new DataFrame with 3 columns: fare, class, embark_town.  Clean your data from all `NaN` values.  Sort your DataFrame by fare in decreasing order.  Sort the same data frame in alphabetical order of the embarked_town.

# %%
new_df = titanic_df[['fare', 'pclass', 'embark_town']]
new_df =new_df.dropna()
new_df=new_df.sort_values(by='embark_town')

# %% [markdown]
# Create a new DataFrame that holds all entries with classes 2 or 3.  Plot the histogram.
# In pandas `&` corresponds to logical `and`, and `|` corresponds to logical `or`

# %%
classes_23 = (titanic_df['pclass']==3)|(titanic_df['pclass']==2)
classes_23
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: pclass, Length: 891, dtype: bool

# %% [markdown]
# Customize row indices such that indices are according to embarked town, drop all `NaN` values, and sort in alphabetical order of embarked town.

# %%
df = titanic_df
df = df.dropna(subset=['embark_town'])  # Drop NaN values in 'Embarked'
df = df.set_index('embark_town')  # Set 'Embarked' as index
df = df.sort_values(by='embark_town')
df
# Out:
#              survived  pclass     sex   age  sibsp      fare   class    who  \
# embark_town
# Cherbourg           1       1  female  35.0      0  512.3292   First  woman
# Cherbourg           1       3    male  12.0      1   11.2417   Third  child
# Cherbourg           0       3    male   NaN      0    7.2250   Third    man
# Cherbourg           0       3    male  15.0      1    7.2292   Third  child
# Cherbourg           1       3  female   NaN      1   22.3583   Third  woman
# ...               ...     ...     ...   ...    ...       ...     ...    ...
# Southampton         0       1    male   NaN      0   35.0000   First    man
# Southampton         0       3    male  25.0      1   17.8000   Third    man
# Southampton         0       3    male  28.0      0    9.5000   Third    man
# Southampton         0       2    male  36.0      0   13.0000  Second    man
# Southampton         1       1    male   4.0      0   81.8583   First  child
#
#              adult_male deck alive  alone
# embark_town
# Cherbourg         False  NaN   yes   True
# Cherbourg         False  NaN   yes  False
# Cherbourg          True  NaN    no   True
# Cherbourg         False  NaN    no  False
# Cherbourg         False    F   yes  False
# ...                 ...  ...   ...    ...
# Southampton        True    C    no   True
# Southampton        True  NaN    no  False
# Southampton        True  NaN    no   True
# Southampton        True  NaN    no   True
# Southampton       False    A   yes  False
#
# [889 rows x 12 columns]

# %% [markdown]
# Let's aggregate data into groups and
# - get the number of entries from each class (i.e. pclass column in csv file)
# - get number of entries from each town
# - get general summary of each class
# - get the number of entries from each class of only survivors
# - plot women, men, children according to class

# %%
# len(titanic_df['pclass'])
# len(titanic_df['embark_town'])
# classes = titanic_df.groupby('pclass').describe()
titanic_df.groupby('pclass')['survived'].value_counts()
titanic_df.groupby('who')['pclass'].value_counts().unstack().plot(xlabel='vero', ylabel='pranjwal', title='MEEMEEEEE')
# Out:
# <Axes: title={'center': 'MEEMEEEEE'}, xlabel='vero', ylabel='pranjwal'>

# %% [markdown]
# plot a bar graph with the number of children, women and men for each class of ticket

# %%
# your code here

# %%
# titanic_df.groupby('pclass')['age'].plot(kind='hist', legend=True, figsize=(5,5), bins=40)
titanic_df.groupby('survived')['age'].plot(kind='hist', legend=True, figsize=(5,5), bins=40)
# Out:
# survived
# 0    Axes(0.125,0.125;0.775x0.755)
# 1    Axes(0.125,0.125;0.775x0.755)
# Name: age, dtype: object
